# %%
import pickle
var_dims = pickle.load(open("var_dims.pkl", "rb"))
var_dims.keys()
# Out:
# dict_keys(['input_dim', 'gene_dim', 'hvg_dim', 'output_dim', 'pert_dim', 'gene_names', 'batch_dim', 'pert_names'])

# %%
len(var_dims['gene_names'])
# Out:
# 2000
