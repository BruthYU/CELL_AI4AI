# %%
import numpy as np
from tqdm import tqdm
import scipy.sparse as sp
import scanpy as sc

def read_adata(path):
    adata = sc.read_h5ad(path)
    return adata
adata = read_adata('./only_hvg/Replogle_only_hvg.h5ad')

# %%
adata.obs
# Out:
#                            gem_group           gene          gene_id  \
# cell_barcode
# AAACCCAAGAATAGTC-3-hepg2           3       KIAA1143  ENSG00000163807
# AAACCCAAGAGGTATT-55-hepg2         55         SEPHS2  ENSG00000179918
# AAACCCAAGAGTGACC-39-hepg2         39         POLR2H  ENSG00000163882
# AAACCCAAGATGGCAC-43-hepg2         43           TFAM  ENSG00000108064
# AAACCCAAGCAACAAT-16-hepg2         16        TMEM214  ENSG00000119777
# ...                              ...            ...              ...
# TTTGTTGTCTGATGGT-14-rpe1          14         SLC1A5  ENSG00000105281
# TTTGTTGTCTGCACCT-44-rpe1          44            MAX  ENSG00000125952
# TTTGTTGTCTGGGCAC-32-rpe1          32        ATP6V0C  ENSG00000185883
# TTTGTTGTCTGTCCCA-37-rpe1          37          MLST8  ENSG00000167965
# TTTGTTGTCTTTCCGG-22-rpe1          22  non-targeting    non-targeting
#
#                               transcript  \
# cell_barcode
# AAACCCAAGAATAGTC-3-hepg2            P1P2
# AAACCCAAGAGGTATT-55-hepg2           P1P2
# AAACCCAAGAGTGACC-39-hepg2           P1P2
# AAACCCAAGATGGCAC-43-hepg2           P1P2
# AAACCCAAGCAACAAT-16-hepg2           P1P2
# ...                                  ...
# TTTGTTGTCTGATGGT-14-rpe1              P1
# TTTGTTGTCTGCACCT-44-rpe1            P1P2
# TTTGTTGTCTGGGCAC-32-rpe1            P1P2
# TTTGTTGTCTGTCCCA-37-rpe1            P1P2
# TTTGTTGTCTTTCCGG-22-rpe1   non-targeting
#
#                                                            gene_transcript  \
# cell_barcode
# AAACCCAAGAATAGTC-3-hepg2                4360_KIAA1143_P1P2_ENSG00000163807
# AAACCCAAGAGGTATT-55-hepg2                 7779_SEPHS2_P1P2_ENSG00000179918
# AAACCCAAGAGTGACC-39-hepg2                 6549_POLR2H_P1P2_ENSG00000163882
# AAACCCAAGATGGCAC-43-hepg2                   8832_TFAM_P1P2_ENSG00000108064
# AAACCCAAGCAACAAT-16-hepg2                9042_TMEM214_P1P2_ENSG00000119777
# ...                                                                    ...
# TTTGTTGTCTGATGGT-14-rpe1                    7976_SLC1A5_P1_ENSG00000105281
# TTTGTTGTCTGCACCT-44-rpe1                     4871_MAX_P1P2_ENSG00000125952
# TTTGTTGTCTGGGCAC-32-rpe1                  675_ATP6V0C_P1P2_ENSG00000185883
# TTTGTTGTCTGTCCCA-37-rpe1                   5115_MLST8_P1P2_ENSG00000167965
# TTTGTTGTCTTTCCGG-22-rpe1   11270_non-targeting_non-targeting_non-targeting
#
#                                                                      sgID_AB  \
# cell_barcode
# AAACCCAAGAATAGTC-3-hepg2   KIAA1143_+_44803075.23-P1P2|KIAA1143_+_4480308...
# AAACCCAAGAGGTATT-55-hepg2  SEPHS2_-_30457178.23-P1P2|SEPHS2_+_30457164.23...
# AAACCCAAGAGTGACC-39-hepg2  POLR2H_+_184081227.23-P1P2|POLR2H_-_184081237....
# AAACCCAAGATGGCAC-43-hepg2    TFAM_+_60145205.23-P1P2|TFAM_-_60145223.23-P1P2
# AAACCCAAGCAACAAT-16-hepg2  TMEM214_-_27255873.23-P1P2|TMEM214_-_27255853....
# ...                                                                      ...
# TTTGTTGTCTGATGGT-14-rpe1     SLC1A5_+_47291839.23-P1|SLC1A5_+_47291829.23-P1
# TTTGTTGTCTGCACCT-44-rpe1       MAX_+_65569008.23-P1P2|MAX_-_65568906.23-P1P2
# TTTGTTGTCTGGGCAC-32-rpe1   ATP6V0C_+_2564168.23-P1P2|ATP6V0C_-_2563995.23...
# TTTGTTGTCTGTCCCA-37-rpe1     MLST8_+_2255502.23-P1P2|MLST8_-_2255521.23-P1P2
# TTTGTTGTCTTTCCGG-22-rpe1             non-targeting_03462|non-targeting_00434
#
#                            mitopercent  UMI_count  z_gemgroup_UMI cell_line
# cell_barcode
# AAACCCAAGAATAGTC-3-hepg2      0.114029    11234.0       -0.611091     hepg2
# AAACCCAAGAGGTATT-55-hepg2     0.165242    45146.0        0.208833     hepg2
# AAACCCAAGAGTGACC-39-hepg2     0.162209    20190.0       -0.025114     hepg2
# AAACCCAAGATGGCAC-43-hepg2     0.071596    23912.0        2.079665     hepg2
# AAACCCAAGCAACAAT-16-hepg2     0.109515     8282.0       -0.214576     hepg2
# ...                                ...        ...             ...       ...
# TTTGTTGTCTGATGGT-14-rpe1      0.062634    15423.0        0.347911      rpe1
# TTTGTTGTCTGCACCT-44-rpe1      0.079629    22228.0        0.767826      rpe1
# TTTGTTGTCTGGGCAC-32-rpe1      0.049527    12377.0       -0.004215      rpe1
# TTTGTTGTCTGTCCCA-37-rpe1      0.061164     8093.0       -0.616659      rpe1
# TTTGTTGTCTTTCCGG-22-rpe1      0.048590    18296.0        1.378922      rpe1
#
# [643413 rows x 10 columns]

# %%
adata.X.max()
# Out:
# 8.355654

# %%
# 按cartessian_key划分细胞
import numpy as np
from tqdm import tqdm
import scipy.sparse as sp
import scanpy as sc

def read_adata(path):
    adata = sc.read_h5ad(path)
    return adata

def iter_adata_rows(
    adata,
    cols=("cell_line", "gene"),
    to_float32: bool = False,
):

    # 1) obs三列一次性取出，避免每行反复做 pandas 索引
    obs_df = adata.obs.loc[:, list(cols)]

    # 2) X：若是稀疏，尽量保证 CSR 以便按行切片更快
    # X = sp.csr_matrix(adata.X)
    
    X = sp.csr_matrix(adata.X)

    is_sparse = sp.issparse(X)

    for i in tqdm(range(adata.n_obs)):
        row_obs = obs_df.iloc[i]

        # 取obs字段
        out = {"i": i}
        for c in cols:
            out[c] = row_obs[c]

        out["x"] = X[i]
        yield out



group_dict = {}
# 用法示例




for item in iter_adata_rows(adata):
    cell_line, gene, x = item["cell_line"], item["gene"], item["x"]
    cell_key = ('0', cell_line, gene)
    if cell_key not in group_dict:
        group_dict[cell_key] = []
    group_dict[cell_key].append(x)
# Out:
# 100%|██████████| 643413/643413 [00:45<00:00, 14241.07it/s]

# %%
group_dict.keys()
# Out:
# dict_keys([('0', 'hepg2', 'KIAA1143'), ('0', 'hepg2', 'SEPHS2'), ('0', 'hepg2', 'POLR2H'), ('0', 'hepg2', 'TFAM'), ('0', 'hepg2', 'TMEM214'), ('0', 'hepg2', 'BAP1'), ('0', 'hepg2', 'MAP2K7'), ('0', 'hepg2', 'UXT'), ('0', 'hepg2', 'SHQ1'), ('0', 'hepg2', 'MRPL37'), ('0', 'hepg2', 'non-targeting'), ('0', 'hepg2', 'NUP153'), ('0', 'hepg2', 'ZNF787'), ('0', 'hepg2', 'SSU72'), ('0', 'hepg2', 'HAMP'), ('0', 'hepg2', 'WDR4'), ('0', 'hepg2', 'NUP107'), ('0', 'hepg2', 'PTPN1'), ('0', 'hepg2', 'PFN1'), ('0', 'hepg2', 'RPS27'), ('0', 'hepg2', 'STAT5B'), ('0', 'hepg2', 'TRAPPC11'), ('0', 'hepg2', 'CSNK2B'), ('0', 'hepg2', 'VPS54'), ('0', 'hepg2', 'MPHOSPH6'), ('0', 'hepg2', 'CCT4'), ('0', 'hepg2', 'TRNT1'), ('0', 'hepg2', 'TPT1'), ('0', 'hepg2', 'SRRM2'), ('0', 'hepg2', 'GFM1'), ('0', 'hepg2', 'PPP1R37'), ('0', 'hepg2', 'NARS2'), ('0', 'hepg2', 'PDCD6IP'), ('0', 'hepg2', 'FBXO42'), ('0', 'hepg2', 'TMEM242'), ('0', 'hepg2', 'DDX5'), ('0', 'hepg2', 'BPTF'), ('0', 'hepg2', 'RRP15'), ('0', 'hepg2', 'PMPCB'), ('0', 'hepg2', 'WBP1'), ('0', 'hepg2', 'PCNX3'), ('0', 'hepg2', 'POLR1D'), ('0', 'hepg2', 'ZMAT2'), ('0', 'hepg2', 'IMP4'), ('0', 'hepg2', 'CENPT'), ('0', 'hepg2', 'POP4'), ('0', 'hepg2', 'UBE2L3'), ('0', 'hepg2', 'ZBTB17'), ('0', 'hepg2', 'DHX37'), ('0', 'hepg2', 'NLE1'), ('0', 'hepg2', 'YPEL5'), ('0', 'hepg2', 'AAAS'), ('0', 'hepg2', 'IPO11'), ('0', 'hepg2', 'RRN3'), ('0', 'hepg2', 'CSE1L'), ('0', 'hepg2', 'WDR70'), ('0', 'hepg2', 'UFM1'), ('0', 'hepg2', 'LETM1'), ('0', 'hepg2', 'INTS7'), ('0', 'hepg2', 'NUDT15'), ('0', 'hepg2', 'TUBB'), ('0', 'hepg2', 'DPH6'), ('0', 'hepg2', 'TIMM23B'), ('0', 'hepg2', 'INTS8'), ('0', 'hepg2', 'RPL6'), ('0', 'hepg2', 'BTF3L4'), ('0', 'hepg2', 'SMN2'), ('0', 'hepg2', 'RPUSD3'), ('0', 'hepg2', 'CIAO1'), ('0', 'hepg2', 'SLC1A5'), ('0', 'hepg2', 'SAE1'), ('0', 'hepg2', 'COX11'), ('0', 'hepg2', 'TAF3'), ('0', 'hepg2', 'RBM10'), ('0', 'hepg2', 'NOL6'), ('0', 'hepg2', 'S100A1'), ('0', 'hepg2', 'SMG5'), ('0', 'hepg2', 'TAF1D'), ('0', 'hepg2', 'TAF11'), ('0', 'hepg2', 'PABPC1'), ('0', 'hepg2', 'CCNC'), ('0', 'hepg2', 'GTF2H4'), ('0', 'hepg2', 'SNRPC'), ('0', 'hepg2', 'DYNLL1'), ('0', 'hepg2', 'RPL8'), ('0', 'hepg2', 'MCM3AP'), ('0', 'hepg2', 'STRAP'), ('0', 'hepg2', 'CENPJ'), ('0', 'hepg2', 'KDM6A'), ('0', 'hepg2', 'PPP6C'), ('0', 'hepg2', 'MED26'), ('0', 'hepg2', 'WTAP'), ('0', 'hepg2', 'RPA1'), ('0', 'hepg2', 'SART3'), ('0', 'hepg2', 'RPL27A'), ('0', 'hepg2', 'NUP43'), ('0', 'hepg2', 'SRA1'), ('0', 'hepg2', 'DKC1'), ('0', 'hepg2', 'CCDC6'), ('0', 'hepg2', 'NARS'), ('0', 'hepg2', 'DBR1'), ('0', 'hepg2', 'RPP40'), ('0', 'hepg2', 'PITRM1'), ('0', 'hepg2', 'URI1'), ('0', 'hepg2', 'NDUFA3'), ('0', 'hepg2', 'TRIAP1'), ('0', 'hepg2', 'BCS1L'), ('0', 'hepg2', 'SMG7'), ('0', 'hepg2', 'USP5'), ('0', 'hepg2', 'SEM1'), ('0', 'hepg2', 'HSD17B10'), ('0', 'hepg2', 'TINF2'), ('0', 'hepg2', 'SF3B4'), ('0', 'hepg2', 'ATRIP'), ('0', 'hepg2', 'MRPL35'), ('0', 'hepg2', 'NUP62'), ('0', 'hepg2', 'IWS1'), ('0', 'hepg2', 'DCTN3'), ('0', 'hepg2', 'NOLC1'), ('0', 'hepg2', 'TSEN2'), ('0', 'hepg2', 'SMNDC1'), ('0', 'hepg2', 'RUVBL1'), ('0', 'hepg2', 'EXOSC5'), ('0', 'hepg2', 'UCHL5'), ('0', 'hepg2', 'INTS5'), ('0', 'hepg2', 'RARS2'), ('0', 'hepg2', 'LRR1'), ('0', 'hepg2', 'H3F3A'), ('0', 'hepg2', 'RPS21'), ('0', 'hepg2', 'SDHC'), ('0', 'hepg2', 'GTF3A'), ('0', 'hepg2', 'TADA1'), ('0', 'hepg2', 'RPL41'), ('0', 'hepg2', 'CCT2'), ('0', 'hepg2', 'EXOSC2'), ('0', 'hepg2', 'SDAD1'), ('0', 'hepg2', 'TFDP1'), ('0', 'hepg2', 'MAD2L1'), ('0', 'hepg2', 'MCMBP'), ('0', 'hepg2', 'OIP5'), ('0', 'hepg2', 'SNRPD1'), ('0', 'hepg2', 'PNO1'), ('0', 'hepg2', 'PHF12'), ('0', 'hepg2', 'RPS18'), ('0', 'hepg2', 'PDCD6'), ('0', 'hepg2', 'ZNF143'), ('0', 'hepg2', 'GRSF1'), ('0', 'hepg2', 'RPL35A'), ('0', 'hepg2', 'YEATS2'), ('0', 'hepg2', 'CCDC174'), ('0', 'hepg2', 'ZNF292'), ('0', 'hepg2', 'PHB2'), ('0', 'hepg2', 'MASTL'), ('0', 'hepg2', 'BTF3'), ('0', 'hepg2', 'OGFOD1'), ('0', 'hepg2', 'ATP2A2'), ('0', 'hepg2', 'CCDC86'), ('0', 'hepg2', 'EIF3B'), ('0', 'hepg2',  ...

# %%
key_list = list(group_dict.keys())
len_list = np.array([len(group_dict[k]) for k in key_list], dtype=np.int64)
max(len_list)
# Out:
# 12013

# %%
import pickle
processed_cartesian_keys = list(group_dict.keys())
# 按1024 shard_size 进行配对的并保存
control_name = "non-targeting"
shard_size = 128
rng = np.random.default_rng(0)
pert_sample_list = []
control_dict = {}

def pad_for_shard_size(array, shard_size):
    N = array.shape[0]
    pad_n = (-N) % shard_size  # number of rows to add
    if pad_n == 0:
        return array, np.empty((0,), dtype=np.int64)
    pad_idx = rng.integers(0, N, size=pad_n)   # with replacement
    array_pad = sp.vstack([array, array[pad_idx]])
    return array_pad, pad_idx

def equal_pert_parts(pert_array, shard_size=1024):
    
    pert_array_pad, _ = pad_for_shard_size(pert_array, shard_size)
    pert_num = pert_array_pad.shape[0]

    
    for sample_idx, i in enumerate(range(0, pert_num, shard_size)):
        pert_sub = pert_array_pad[i:i+shard_size]
        sample = {
            "cartesian_key": pck,
            "cell_matrix": pert_sub,
        }
        pert_sample_list.append(sample)


for pck in tqdm(processed_cartesian_keys):
    if pck[2] == control_name:
        
        control_dict[pck] = sp.vstack(group_dict[pck], format="csr")
    else:
        pert_array = sp.vstack(group_dict[pck], format="csr")
        equal_pert_parts(pert_array, shard_size=shard_size)
    

len(pert_sample_list)

with open(f"pert_sample_list.pkl", "wb") as f:
    pickle.dump(pert_sample_list, f)

with open(f"control_dict.pkl", "wb") as f:
    pickle.dump(control_dict, f)
# Out:
#   0%|          | 0/5763 [00:00<?, ?it/s]
# 100%|██████████| 5763/5763 [00:08<00:00, 676.81it/s]
