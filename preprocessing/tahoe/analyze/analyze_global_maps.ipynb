# %%
# /mnt/shared-storage-gpfs2/beam-gpfs02/yulang/datasets/by_plate/cache
import pickle
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import scipy.sparse as sp

global_maps = pickle.load(open("/mnt/shared-storage-gpfs2/beam-gpfs02/yulang/datasets/by_plate/cache/global_maps.pkl", "rb"))

# %%
global_maps.keys()
# Out:
# dict_keys(['pert_onehot_map', 'batch_onehot_map', 'cell_type_onehot_map'])

# %%
global_keys = {}
global_keys["cell_line"] = sorted(global_maps['cell_type_onehot_map'].keys())
global_keys["drugname_drugconc"] = sorted(global_maps['pert_onehot_map'].keys())
global_keys["plate"] = sorted(global_maps['batch_onehot_map'].keys())

global_keys
with open("global_keys.pkl", "wb") as f:
    pickle.dump(global_keys, f)
