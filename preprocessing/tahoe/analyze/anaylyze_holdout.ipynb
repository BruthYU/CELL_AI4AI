# %%
import anndata as ad
import os

root_path = "/mnt/shared-storage-gpfs2/beam-gpfs02/yulang/datasets/tahoe_holdout/holdout_plate1.h5"

adata = ad.read_h5ad(root_path)
adata.obsm['X_hvg'].max()
# Out:
# 283.5668

# %%
adata.obsm['X_hvg']
